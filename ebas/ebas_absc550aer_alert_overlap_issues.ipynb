# %%
import pyaerocom as pya
# Out:
# Initating pyaerocom configuration
# Checking server configuration ...
# Checking access to: /lustre/storeA
# Access to lustre database: True
# Init data paths for lustre
# Expired time: 0.025 s

# %%
data = pya.io.ReadEbas().read('absc550aer', station_names='Alert*', datalevel=2, REMOVE_INVALID_FLAGS=True)
data
# Out:
# Reading file 1 of 26 (ReadEbas)
# Reading file 3 of 26 (ReadEbas)
# Reading file 5 of 26 (ReadEbas)
# Reading file 7 of 26 (ReadEbas)
# Reading file 9 of 26 (ReadEbas)
# Reading file 11 of 26 (ReadEbas)
# Reading file 13 of 26 (ReadEbas)
# Reading file 15 of 26 (ReadEbas)
# Reading file 17 of 26 (ReadEbas)
# Reading file 19 of 26 (ReadEbas)
# Reading file 21 of 26 (ReadEbas)
# Reading file 23 of 26 (ReadEbas)
# Reading file 25 of 26 (ReadEbas)
# UngriddedData <networks: ['EBASMC']; vars: ['absc550aer']; instruments: ['Radiance-Research_PSAP-3W_ALT', 'Radiance-Research_PSAP-1W_ALT', 'Radiance-Research_PSAP-1W_ALT_pm10', 'Radiance-Research_PSAP-3W_ALT_pm10', 'Magee_AE31_ALT', 'Magee_Aethalometer_ALT'];No. of stations: 26

# %%
stat = data.to_station_data('Alert', 'absc550aer', freq='daily')

# %%
stat.plot_timeseries('absc550aer', freq='daily', add_overlaps=True)

# %%
stat.overlap['absc550aer'].resample('D')
# Out:
# DatetimeIndexResampler [freq=<Day>, axis=0, closed=left, label=left, convention=start, base=0]
