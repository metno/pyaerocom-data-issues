# %%
import pyaerocom as pya
# Out:
# Initating pyaerocom configuration
# Checking server configuration ...
# Checking access to: /lustre/storeA
# Access to lustre database: True
# Init data paths for lustre
# Expired time: 0.025 s

# %%
d0 =  pya.io.ReadEbas().read('scatc550aer', station_names='Egbert')
d0
# Out:
# Reading file 1 of 9 (ReadEbas)
# Reading file 2 of 9 (ReadEbas)
# Reading file 3 of 9 (ReadEbas)
# Reading file 4 of 9 (ReadEbas)
# Reading file 5 of 9 (ReadEbas)
# Reading file 6 of 9 (ReadEbas)
# Reading file 7 of 9 (ReadEbas)
# Reading file 8 of 9 (ReadEbas)
# Reading file 9 of 9 (ReadEbas)
# UngriddedData <networks: ['EBASMC']; vars: ['scatc550aer']; instruments: ['TSI_3563_EGB', 'TSI_3563_EGB_pm10', 'TSI_Neph_EGB'];No. of stations: 9

# %%
d0.station_name
# Out:
# ['Egbert',
#  'Egbert',
#  'Egbert',
#  'Egbert',
#  'Egbert',
#  'Egbert',
#  'Egbert',
#  'Egbert',
#  'Egbert']

# %%
s0 = d0.to_station_data('Egbert', 'scatc550aer')

# %%
s0.plot_timeseries('scatc550aer')

# %%
d1 =  pya.io.ReadEbas().read('scatc550dryaer', station_names='Egbert')
d1
# Out:
# Reading file 1 of 9 (ReadEbas)
# Reading file 2 of 9 (ReadEbas)
# Reading file 3 of 9 (ReadEbas)
# Reading file 4 of 9 (ReadEbas)
# Reading file 5 of 9 (ReadEbas)
# Reading file 6 of 9 (ReadEbas)
# Reading file 7 of 9 (ReadEbas)
# Reading file 8 of 9 (ReadEbas)
# Reading file 9 of 9 (ReadEbas)
# UngriddedData <networks: ['EBASMC']; vars: ['scatc550dryaer']; instruments: ['TSI_3563_EGB', 'TSI_3563_EGB_pm10', 'TSI_Neph_EGB'];No. of stations: 9

# %%
d1.to_station_data('Egbert', 'scatc550dryaer').plot_timeseries('scatc550dryaer')
